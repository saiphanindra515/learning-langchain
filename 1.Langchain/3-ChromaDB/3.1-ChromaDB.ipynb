# %%
from langchain_chroma import Chroma
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.embeddings import OllamaEmbeddings

# %%
loader = TextLoader("speech.txt")
docs = loader.load()

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=200, chunk_overlap=30)
splitter_docs = text_splitter.split_documents(docs)

# %%
embeddings = OllamaEmbeddings()
vectorDB = Chroma.from_documents(splitter_docs, embedding = embeddings)
# Out:
# /var/folders/r2/6qh6vbp5595fvl9qqtxnz4980000gn/T/ipykernel_6545/2967333541.py:1: LangChainDeprecationWarning: The class `OllamaEmbeddings` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import OllamaEmbeddings``.
#   embeddings = OllamaEmbeddings()

# %%
query = "It is held annually between March and May. It has an exclusive window in the Future Tours Programme of the International Cricket Council, resulting in fewer international tours occurring during the seasons.[3] It is also the most viewed Indian sports event, as per the Broadcast Audience Research"
similar_docs = vectorDB.similarity_search(query)
similar_docs
# Out:
# [Document(id='d107f79b-17a9-45cf-8425-561dccea7766', metadata={'source': 'speech.txt'}, page_content='tours occurring during the seasons.[3] It is also the most viewed Indian sports event, as per the Broadcast Audience Research Council.[4][5]'),
#  Document(id='8f30031e-1297-4079-b1e7-ad128eb632b2', metadata={'source': 'speech.txt'}, page_content='It is the 11th richest sporting league in the world by revenue.'),
#  Document(id='45c670ec-ccbd-4656-980c-4be558f5e1eb', metadata={'source': 'speech.txt'}, page_content='who won the 2025 season after defeating the Punjab Kings in the final.'),
#  Document(id='d3e8591f-094b-4371-b517-cac730360381', metadata={'source': 'speech.txt'}, page_content='value, after the National Football League.[13] In 2023, the league sold its media rights for the next four seasons for US$6.4 billion to Viacom18 and Star Sports,[14] which meant that each IPL match')]
