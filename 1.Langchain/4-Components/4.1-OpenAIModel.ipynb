# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4o")
print(llm)
# Out:
# output_version=None profile={'name': 'GPT-4o', 'release_date': '2024-05-13', 'last_updated': '2024-08-06', 'open_weights': False, 'max_input_tokens': 128000, 'max_output_tokens': 16384, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'pdf_inputs': True, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True} client=<openai.resources.chat.completions.completions.Completions object at 0x12dac64d0> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x12d87c9d0> root_client=<openai.OpenAI object at 0x129724850> root_async_client=<openai.AsyncOpenAI object at 0x12d87c7c0> model_name='gpt-4o' model_kwargs={} openai_api_key=SecretStr('**********') openai_proxy=None stream_usage=True stream_chunk_timeout=120.0

# %%
# Input and get response from the model
response = llm.invoke("What IPL Match will be there today?")
print(response)
# Out:
# content="I'm unable to provide real-time information or updates on specific events such as IPL matches. To find out which IPL match is scheduled for today, I recommend checking the official IPL website, a sports news website, or a sports app that provides live updates and schedules." additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 52, 'prompt_tokens': 15, 'total_tokens': 67, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_b7e14c395d', 'id': 'chatcmpl-Dk7nyDirrG1zABrpbTNykL848Yo4i', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019e6970-d15b-7033-9572-5ea0777575a3-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 15, 'output_tokens': 52, 'total_tokens': 67, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
### ChatPromptTemplate
from langchain_core.prompts import ChatPromptTemplate
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "You are an expert AI Engineer. Provide answers to my questions"),
        ("user", "{input}")
    ]
)

prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an expert AI Engineer. Provide answers to my questions'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
# Out:
# content='Langchain is a framework designed to simplify the development of language model-based applications. It provides a cohesive set of tools and abstractions to enable developers to build complex applications that can interact with large language models (LLMs) more efficiently and effectively. Langchain typically focuses on modularizing key components of LLM-based applications, such as prompt management, model selection, and chaining together multiple operations, allowing for more robust and maintainable software.\n\nKey features of Langchain often include:\n\n1. **Prompt Management:** Tools to dynamically construct, customize, and manage prompts for language models, improving the quality and relevance of generated outputs.\n\n2. **Model Integration:** A seamless way to integrate various LLMs or APIs, making it easier to switch or use multiple models within the same application.\n\n3. **Chains and Pipelines:** Constructs that allow developers to link different tasks or steps in a pipeline, such as preprocessing input data, calling a language model, and post-processing the results.\n\n4. **Memory:** Persistence capabilities to retain information across different interactions or sessions, allowing applications to maintain context or learn over time.\n\n5. **Tooling and Extensibility:** Facilitating the integration with external tools, APIs, or databases, thereby enhancing the capabilities of language model applications.\n\nLangchain is particularly useful in scenarios where there is a need to build complex workflows that leverage the capabilities of LLMs, such as chatbots, intelligent agents, or automated data processing systems.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 292, 'prompt_tokens': 28, 'total_tokens': 320, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_727a239e01', 'id': 'chatcmpl-Dk7wYEb0sQI4uHoAQZrTGXXTLgk6d', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019e6978-eac3-7282-b0f2-3237eaf3f659-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 28, 'output_tokens': 292, 'total_tokens': 320, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
## stroutput Parser

from langchain_core.output_parsers import StrOutputParser
output_parser = StrOutputParser()
chain = prompt | llm | output_parser
response = chain.invoke(input="What is Langchain?")
print(response)
# Out:
# LangChain is a framework designed to facilitate the development of applications that are powered by language models. It provides a streamlined way to build applications that combine multiple components and leverage large language models (LLMs). LangChain supports various functionalities, including the creation of chatbots, decision-making systems, and solutions that involve natural language understanding and processing.
#
# Key features of LangChain include:
#
# 1. **Chainable Components**: LangChain allows developers to chain together different components, such as language models, data retrievers, and custom logic, to build complex LLM-based workflows.
#
# 2. **Integration with Language Models**: LangChain is designed to seamlessly integrate with various LLMs, allowing developers to leverage their capabilities in application building.
#
# 3. **Template Support**: It supports templating and generation tools, which can assist in creating prompts and queries that guide the language model's responses.
#
# 4. **Data Augmentation**: LangChain assists in managing and augmenting data, which can be useful for training and fine-tuning models, as well as for retrieval-based tasks.
#
# 5. **Extensibility and Modular Design**: The framework is designed to be modular, enabling developers to extend it with custom functionalities and adapt it to specific application needs.
#
# Overall, LangChain simplifies the process of building sophisticated applications that utilize the powerful capabilities of language models by providing a structured and flexible development framework.
